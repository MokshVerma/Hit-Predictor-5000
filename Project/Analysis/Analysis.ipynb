# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_csv('Dataset(Analysis)(processed lyrics).csv')
df.head()
df1 = pd.DataFrame(df[['Artist Hit', 'Hit']])

# %%
sn.pairplot(df1, hue='Hit')
